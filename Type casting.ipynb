# %%
#Type casting
print("Int to float")
i=123
print(i, type(i))
i1=float(i)
print(i1,type(i1))
# Out:
# Int to float
# 123 <class 'int'>
# 123.0 <class 'float'>

# %%
print("int to str")
i=1234
print(i,type(i))
i2=str(i)
print(i2,type(i2))
# Out:
# int to str
# 1234 <class 'int'>
# 1234 <class 'str'>

# %%
print("int to bool 'True'")
i=12
print(i, type(i))
i3=bool(i)
print(i3, type(i3))
# Out:
# int to bool 'True'
# 12 <class 'int'>
# True <class 'bool'>

# %%
print("int nto bool 'False'")
i=0
print(i, type(i))
i4=bool(i)
print(i4, type(i4))
# Out:
# int nto bool 'False'
# 0 <class 'int'>
# False <class 'bool'>

# %%
print("int to complex")
i=100
print(i, type (i))
i5=complex(i)
print(i5, type(i5))
# Out:
# int to complex
# 100 <class 'int'>
# (100+0j) <class 'complex'>

# %%
print ("str to int")
s="23"
print(s,type(s))
s1= int(s)
print(s1, type(s1))
# Out:
# str to int
# 23 <class 'str'>
# 23 <class 'int'>

# %%
print("str to float")
s="11.45"
print(s, type(s))
s2=float(s)
print(s2, type(s2))
# Out:
# str to float
# 11.45 <class 'str'>
# 11.45 <class 'float'>

# %%
print("str to bool 'True'")
s="10"
print(s, type(s))
s3= bool(s)
print(s3, type(s3))
# Out:
# str to bool 'True'
# 10 <class 'str'>
# True <class 'bool'>

# %%
print("str to bool 'False'")
s=""
print(s,type(s))
s4= bool(s)
print(s4, type(s4))
# Out:
# str to bool 'False'
#  <class 'str'>
# False <class 'bool'>

# %%
print("str to complex")
s="17"
print(s, type(s))
s5=complex(s)
print(s5, type(s5))
# Out:
# str to complex
# 17 <class 'str'>
# (17+0j) <class 'complex'>

# %%
print("float to int")
f=33.56
print (f, type(f))
f1=int(f)
print(f1,type(f1))
# Out:
# float to int
# 33.56 <class 'float'>
# 33 <class 'int'>

# %%
print("float to str")
f=66.23
print(f, type(f))
f2= str(f)
print(f2, type(f2))
# Out:
# float to str
# 66.23 <class 'float'>
# 66.23 <class 'str'>

# %%
print("float to bool'True'")
f= 33.55
print(f, type(f))
f3=bool(f)
print(f3, type(f3))
# Out:
# float to bool'True'
# 33.55 <class 'float'>
# True <class 'bool'>

# %%
print("float to bool 'false'")
f=0.0
print(f, type(f))
f4=bool(f)
print(f4, type(f4))
# Out:
# float to bool 'false'
# 0.0 <class 'float'>
# False <class 'bool'>

# %%
print("float to complex")
f=43.2
print(f, type(f))
f5=complex(f)
print(f5, type(f5))
# Out:
# float to complex
# 43.2 <class 'float'>
# (43.2+0j) <class 'complex'>

# %%
print("bool to int")
b=True
print(b, type(b))
b1=int(b)
print(b1, type(b1))
# Out:
# bool to int
# True <class 'bool'>
# 1 <class 'int'>

# %%
print("bool to float")
b=False
print(b, type(b))
b2=float(b)
print(b2, type(b2))
# Out:
# bool to float
# False <class 'bool'>
# 0.0 <class 'float'>

# %%
print("bool to complex")
b= True
print(b, type (b))
b3= complex(b)
print(b3, type(b3))
# Out:
# bool to complex
# True <class 'bool'>
# (1+0j) <class 'complex'>

# %%
print("bool to str")
b=False
print(b, type(b))
b4=str(b)
print(b4, type(b4))
# Out:
# bool to str
# False <class 'bool'>
# False <class 'str'>

# %%
print("complex to int")
c= 2+5j
print(c, type(c))
c1= int(c)
print(c1, type(c1))
# Out:
# complex to int
# (2+5j) <class 'complex'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 4
#       2 c= 2+5j
#       3 print(c, type(c))
# ----> 4 c1= int(c)
#       5 print(c1, type(c1))
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
print("complex to float")
c= 2+3j
print(c, type(c))
c2= float(c)
print(c2, type(c2))
# Out:
# complex to float
# (2+3j) <class 'complex'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 4
#       2 c= 2+3j
#       3 print(c, type(c))
# ----> 4 c2= float(c)
#       5 print(c2, type(c2))
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
print("complex to bool 'True'")
c= 5+3j
print(c,type(c))
c3= bool(c)
print(c3, type(c3))
# Out:
# complex to bool 'True'
# (5+3j) <class 'complex'>
# True <class 'bool'>

# %%
print("Complex to bool 'False'")
c= 0+0j
print(c, type(c))
c4= bool(c)
print(c4, type(c4))
# Out:
# Complex to bool 'False'
# 0j <class 'complex'>
# False <class 'bool'>

# %%
print("complex to str")
c= 5+3j
print(c, type(c))
c5= str(c)
print(c5, type(c5))
# Out:
# complex to str
# (5+3j) <class 'complex'>
# (5+3j) <class 'str'>
