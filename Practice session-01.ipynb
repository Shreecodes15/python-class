# %% [markdown]
# 31-01-26 Saturday
# Test 01

# %%
print(10+5*2)#-- 10+10
print((10+5)*2)#-- 15*2
print(20-4**2) #-- 20-16
print(100//5*2) #-- 20*2
print(18%5+2) #-- 3+2
# Out:
# 20
# 30
# 4
# 40
# 5

# %%
print(2**3**2) #-- 2**9
print(4*2**3) #-- 4*8
print(16//2**2)#-- 16//4
print(9+6*2**2)#-- 4*6+9
print(8-2**2*2) #8-(4*2)
# Out:
# 512
# 32
# 4
# 33
# 0

# %%
print(10>5 and 5>2) #--True
# Out:
# True

# %%
print(10>5 or 5<2) #True
# Out:
# True

# %%
print(not 10>5) #False
# Out:
# False

# %%
print(True or False and False) #False
# Out:
# True

# %%
print(5<10<20) #True
# Out:
# True

# %%
x=5
x+=3*2
print(x) # x= 5+6
# Out:
# 11

# %%
x=10
x*=2+3
print(x) # x=10*5
# Out:
# 50

# %%
x=5
x=x==5
print(x)# True
# Out:
# True

# %%
x=2
x**=2+1
print(x) # x=2**3
# Out:
# 8

# %%
x=1
x+=x==1
print(x)# x=1+1, False
# Out:
# 2

# %%
print(5 and 0 or 8)
# Out:
# 8

# %%
print(0 or 5 and 8)
# Out:
# 8

# %%
print(True==False or True) #True
# Out:
# True

# %%
print (False == False and False )#False
# Out:
# False

# %%
print(not True==False) #true
# Out:
# True

# %% [markdown]
# *********Part-A*********

# %%
#01 write a program to check if the given character is present in a string entered by user 
s= input("Enter character to search in hello")
if s in "HELLOhello":
    print("Your character {} is present in hello".format(s))
else:
    print("Oops! character not in hello")
# Out:
# Enter character to search in hello h
# Your character h is present in hello

# %%
#02 write a program to check if a given number is predefined list of prime numbers 
l1=[1,3,5,7,11,13]
a=int(input("enter any number under 15 to check prime number "))
if a in l1:
    print(a,"Is prime number")
else:
    print(a,"Is not a prime number ")
# Out:
# enter any number under 15 to check prime number  7
# 7 Is prime number

# %%
#03 write a program to check if a user's chosen username is already in list of existing username
list=["Alice","Bob","John123"]
user=input("Enter username: ")
if user in list:
    print(user, "Available")
else:
    print("###wrong username###",user)
# Out:
# Enter username:  Alice
# Alice Available

# %%
# 04 WAP to check if a word is a part of given sentence input both word and sentence
word=input("Enter your word to check")
s=input("Enter your sentence")
if word in s:
    print(word, "present in", s)
else:
    print(word, "Unavailable in",s)
# Out:
# Enter your word to check sun
# Enter your sentence the sun rises in the east
# sun present in the sun rises in the east

# %%
#05 WAP to check if an item is not present in shopping cart list and add if it is missing
cart=["Bread","eggs"]
item=input("add item")
if item not in cart:
    print(item, "was not in cart, now added")
else:
    print(item, "already in cart")
# Out:
# add item milk
# milk was not in cart, now added

# %% [markdown]
# *********Part-B*********

# %%
#01 WAP to check if two variables refer to the same object in memory
a=[1,2]
b=a
if a is b:
    print("a and b refer to the same object")
else:
    print("different object")
# Out:
# a and b refer to the same object

# %%
#02 WAP to input two list and check if they are the same object or different object
l1=eval(input("enter list 1"))
l2=eval(input("enter list 2"))
if l1 is not l2:
    print("list1",l1,"is not same object as","list2",l2)
else:
    print("same object")
# Out:
# enter list 1 [1,2,3]
# enter list 2 [1,2,3]
# list1 [1, 2, 3] is not same object as list2 [1, 2, 3]

# %%
#03 WAP to check if a variable is none and print a message if it is 
s=None
if s is None:
    print("Variable is None")
# Out:
# Variable is None

# %%
#04 WAP to check if a user's input is not 'None ' and proceed only if it is not
i=eval(input("enter value"))
if i is None:
    print("input is None")
else:
    print('variable',i,"is not None")
# Out:
# enter value "Hello"
# variable Hello is not None

# %%
#05 WAP to compatre two strings and check if they are the same object or just equal in value 
s1="apple"
s2="".join(['a','p','p','l','l','e'])
if s1 is s2:
    print("string same ")
else:
    print("s1 and s2 has same value but different object")
# Out:
# s1 and s2 has same value but different object
